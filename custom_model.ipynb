# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\agung\WebApp_YoloV8

# %%
# Pip install method (recommended)

# %pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.13 torch-2.1.2+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# Setup complete  (8 CPUs, 15.8 GB RAM, 377.0/476.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# %pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="HToOskN38kYXUwcL2969")
project = rf.workspace("project-ta-gt8x4").project("ta-6ybjx")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# [WinError 2] The system cannot find the file specified: 'c:\\Users\\agung\\WebApp_YoloV8/datasets'
# c:\Users\agung\WebApp_YoloV8
# The syntax of the command is incorrect.
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/60/e7/a6dedca760db7a4686fd3b6053487ad4ad4d8f0591295dc8a9cf35269c42/opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\agung\anaconda3\Lib\site-packages\~v2'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# annotated-types               0.6.0
# archspec                      0.2.1
# array-record                  0.4.1
# asttokens                     2.4.1
# astunparse                    1.6.3
# attrs                         23.1.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# beautifulsoup4                4.12.2
# bleach                        6.1.0
# blinker                       1.8.2
# blis                          0.7.11
# boltons                       23.0.0
# Brotli                        1.0.9
# cachetools                    5.3.2
# catalogue                     2.0.10
# category-encoders             2.6.2
# certifi                       2023.7.22
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=C:/Users/agung/WebApp_YoloV8/TA-5/data.yaml epochs=100 imgsz=640 plots=True patience=0
# Out:
# c:\Users\agung\WebApp_YoloV8
# New https://pypi.org/project/ultralytics/8.2.28 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.10.13 torch-2.1.2+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# ...

# %%
# %ls {HOME}/runs/detect/train2/
# Out:
# Parameter format not correct - "runs".

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# c:\Users\agung\WebApp_YoloV8
# Ultralytics YOLOv8.0.196  Python-3.10.13 torch-2.1.2+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# Model summary (fused): 168 layers, 11133711 parameters, 0 gradients, 28.5 GFLOPs
#
# val: Scanning C:\Users\agung\WebApp_YoloV8\TA-5\valid\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# val: Scanning C:\Users\agung\WebApp_YoloV8\TA-5\valid\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 135, len(boxes) = 184. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/7 [00:00<?, ?it/s]
# ...
